# %% [markdown]
# # Information from satellite source
# este saca la data satelital de los puntos donde están las estaciones

# %%
import pandas as pd

# %%
prec = pd.read_parquet('data/fedearroz_prec_diaria_2024.parquet')

# %% [markdown]
# se saca el resumen para iterar con la fuente satelital

# %%
info = prec.groupby(['lat','lon','dpto','mun','station']).agg(
    max_date = ('date','max'), 
    min_date=('date','min'),
    porc_nan=('prec', lambda x: round(x.isna().mean() * 100, 2))
).reset_index()
info.head()
# Out:
#        lat       lon   dpto          mun                           station  \
# 0  2.69814 -75.29815  HUILA  CAMPOALEGRE  FEDEARROZ_CAMPOALEGRE_ALTAGRACIA
# 1  2.88457 -75.44166  HUILA      PALERMO       FEDEARROZ_PALERMO_ASOJUNCAL
# 2  3.08083 -75.19083  HUILA        TELLO         FEDEARROZ_TELLO_SAN_DIEGO
# 3  3.24609 -75.23978  HUILA         AIPE      FEDEARROZ_AIPE_PIEDRAPINTADA
# 4  3.30278 -73.56722   META      GRANADA    FEDEARROZ_GRANADA_LOS_NARANJOS
#
#     max_date   min_date  porc_nan
# 0 2024-08-15 2011-10-11      3.58
# 1 2022-10-15 2011-08-24     11.15
# 2 2024-05-06 2017-01-10     11.29
# 3 2024-08-15 2011-10-11     12.76
# 4 2024-05-06 2011-09-15      8.90

# %% [markdown]
# ## Extraction of info from Chirps

# %%
for index, row in info.iterrows():
    print(index)
    lat = round(row['lat'], 6)
    lon = round(row['lon'], 6)
    #star_month= row['max_date'].strftime('%m-%d')
    #end_month= row['min_date'].strftime('%m-%d')
    end_year= row['min_date'].strftime('%Y')
    start_year= row['max_date'].strftime('%Y')
    rest=int(start_year)-int(end_year)+2
    print(rest)
    print(start_year)
    print(lat)
    print(lon)
    # !python getDataFromCubePoint.py --startDate "01-01" --endDate "12-31" --variable "agera5-precipitation" --numberofyears {rest} --lastYear {start_year} --downloadpath "/home/jupyter/agera5_data/" --x {lon} --y {lat}
    #!python getDataFromCubePoint.py --startDate "01-01" --endDate "03-01" --variable "chirps-precipitation" --numberofyears 2 --lastYear 2024 --downloadpath "/home/jupyter/" --x {lon} --y {lat}
# Out:
# 0
# 15
# 2024
# 2.69814
# -75.29815
# -75.29815 2.69814
# {'startDt': '2024-01-01', 'endDt': '2024-12-31', 'lon': '-75.29815', 'lat': '2.69814', 'variableName': 'agera5-precipitation'}
# {'startDt': '2023-01-01', 'endDt': '2023-12-31', 'lon': '-75.29815', 'lat': '2.69814', 'variableName': 'agera5-precipitation'}
# {'startDt': '2022-01-01', 'endDt': '2022-12-31', 'lon': '-75.29815', 'lat': '2.69814', 'variableName': 'agera5-precipitation'}
# {'startDt': '2021-01-01', 'endDt': '2021-12-31', 'lon': '-75.29815', 'lat': '2.69814', 'variableName': 'agera5-precipitation'}
# {'startDt': '2020-01-01', 'endDt': '2020-12-31', 'lon': '-75.29815', 'lat': '2.69814', 'variableName': 'agera5-precipitation'}
# {'startDt': '2019-01-01', 'endDt': '2019-12-31', 'lon': '-75.29815', 'lat': '2.69814', 'variableName': 'agera5-precipitation'}
# {'startDt': '2018-01-01', 'endDt': '2018-12-31', 'lon': '-75.29815', 'lat': '2.69814', 'variableName': 'agera5-precipitation'}
# {'startDt': '2017-01-01', 'endDt': '2017-12-31', 'lon': '-75.29815', 'lat': '2.69814', 'variableName': 'agera5-precipitation'}
# {'startDt': '2016-01-01', 'endDt': '2016-12-31', 'lon': '-75.29815', 'lat': '2.69814', 'variableName': 'agera5-precipitation'}
# {'startDt': '2015-01-01', 'endDt': '2015-12-31', 'lon': '-75.29815', 'lat': '2.69814', 'variableName': 'agera5-precipitation'}
# {'startDt': '2014-01-01', 'endDt': '2014-12-31', 'lon': '-75.29815', 'lat': '2.69814', 'variableName': 'agera5-precipitation'}
# {'startDt': '2013-01-01', 'endDt': '2013-12-31', 'lon': '-75.29815', 'lat': '2.69814', 'variableName': 'agera5-precipitation'}
# {'startDt': '2012-01-01', 'endDt': '2012-12-31', 'lon': '-75.29815', 'lat': '2.69814', 'variableName': 'agera5-precipitation'}
# {'startDt': '2011-01-01', 'endDt': '2011-12-31', 'lon': '-75.29815', 'lat': '2.69814', 'variableName': 'agera5-precipitation'}
# {'startDt': '2010-01-01', 'endDt': '2010-12-31', 'lon': '-75.29815', 'lat': '2.69814', 'variableName': 'agera5-precipitation'}
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# Requested from 2011-01-01 to 2011-12-31
# Downloaded file saved to: None
# Requested from 2017-01-01 to 2017-12-31
# Downloaded file saved to: None
# Requested from 2023-01-01 to 2023-12-31
# Downloaded file saved to: None
# Request for interval ('2024-01-01', '2024-12-31') generated an exception: 500 Server Error: Internal Server Error for url: https://zarr-query-api-rv7rkv4opa-uc.a.run.app/v1/getdataOnePoint
# Requested from 2016-01-01 to 2016-12-31
# Downloaded file saved to: None
# Requested from 2013-01-01 to 2013-12-31
# Downloaded file saved to: None
# Requested from 2012-01-01 to 2012-12-31
# Downloaded file saved to: None
# Requested from 2022-01-01 to 2022-12-31
# Downloaded file saved to: None
# Requested from 2010-01-01 to 2010-12-31
# Downloaded file saved to: None
# Requested from 2014-01-01 to 2014-12-31
# Downloaded file saved to: None
# Requested from 2019-01-01 to 2019-12-31
# Downloaded file saved to: None
# Requested from 2015-01-01 to 2015-12-31
# Downloaded file saved to: None
# Requested from 2018-01-01 to 2018-12-31
# Downloaded file saved to: None
# Requested from 2020-01-01 to 2020-12-31
# Downloaded file saved to: None
# Requested from 2021-01-01 to 2021-12-31
# Downloaded file saved to: None
# 1
# 13
# 2022
# 2.88457
# -75.44166
# -75.44166 2.88457
# {'startDt': '2022-01-01', 'endDt': '2022-12-31', 'lon': '-75.44166', 'lat': '2.88457', 'variableName': 'agera5-precipitation'}
# {'startDt': '2021-01-01', 'endDt': '2021-12-31', 'lon': '-75.44166', 'lat': '2.88457', 'variableName': 'agera5-precipitation'}
# {'startDt': '2020-01-01', 'endDt': '2020-12-31', 'lon': '-75.44166', 'lat': '2.88457', 'variableName': 'agera5-precipitation'}
# {'startDt': '2019-01-01', 'endDt': '2019-12-31', 'lon': '-75.44166', 'lat': '2.88457', 'variableName': 'agera5-precipitation'}
# {'startDt': '2018-01-01', 'endDt': '2018-12-31', 'lon': '-75.44166', 'lat': '2.88457', 'variableName': 'agera5-precipitation'}
# {'startDt': '2017-01-01', 'endDt': '2017-12-31', 'lon': '-75.44166', 'lat': '2.88457', 'variableName': 'agera5-precipitation'}
# {'startDt': '2016-01-01', 'endDt': '2016-12-31', 'lon': '-75.44166', 'lat': '2.88457', 'variableName': 'agera5-precipitation'}
# {'startDt': '2015-01-01', 'endDt': '2015-12-31', 'lon': '-75.44166', 'lat': '2.88457', 'variableName': 'agera5-precipitation'}
# {'startDt': '2014-01-01', 'endDt': '2014-12-31', 'lon': '-75.44166', 'lat': '2.88457', 'variableName': 'agera5-precipitation'}
# {'startDt': '2012-01-01', 'endDt': '2012-12-31', 'lon': '-75.44166', 'lat': '2.88457', 'variableName': 'agera5-precipitation'}
# {'startDt': '2013-01-01', 'endDt': '2013-12-31', 'lon': '-75.44166', 'lat': '2.88457', 'variableName': 'agera5-precipitation'}
# {'startDt': '2011-01-01', 'endDt': '2011-12-31', 'lon': '-75.44166', 'lat': '2.88457', 'variableName': 'agera5-precipitation'}
# {'startDt': '2010-01-01', 'endDt': '2010-12-31', 'lon': '-75.44166', 'lat': '2.88457', 'variableName': 'agera5-precipitation'}
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# Requested from 2019-01-01 to 2019-12-31
# Downloaded file saved to: None
# Requested from 2014-01-01 to 2014-12-31
# Downloaded file saved to: None
# Requested from 2011-01-01 to 2011-12-31
# Downloaded file saved to: None
# Requested from 2021-01-01 to 2021-12-31
# Downloaded file saved to: None
# Requested from 2022-01-01 to 2022-12-31
# Downloaded file saved to: None
# Requested from 2018-01-01 to 2018-12-31
# Downloaded file saved to: None
# Requested from 2017-01-01 to 2017-12-31
# Downloaded file saved to: None
# Requested from 2010-01-01 to 2010-12-31
# Downloaded file saved to: None
# Requested from 2020-01-01 to 2020-12-31
# Downloaded file saved to: None
# Requested from 2016-01-01 to 2016-12-31
# Downloaded file saved to: None
# Requested from 2012-01-01 to 2012-12-31
# Downloaded file saved to: None
# Requested from 2013-01-01 to 2013-12-31
# Downloaded file saved to: None
# Requested from 2015-01-01 to 2015-12-31
# Downloaded file saved to: None
# 2
# 9
# 2024
# 3.08083
# -75.19083
# -75.19083 3.08083
# {'startDt': '2024-01-01', 'endDt': '2024-12-31', 'lon': '-75.19083', 'lat': '3.08083', 'variableName': 'agera5-precipitation'}
# {'startDt': '2023-01-01', 'endDt': '2023-12-31', 'lon': '-75.19083', 'lat': '3.08083', 'variableName': 'agera5-precipitation'}
# {'startDt': '2022-01-01', 'endDt': '2022-12-31', 'lon': '-75.19083', 'lat': '3.08083', 'variableName': 'agera5-precipitation'}
# {'startDt': '2021-01-01', 'endDt': '2021-12-31', 'lon': '-75.19083', 'lat': '3.08083', 'variableName': 'agera5-precipitation'}
# {'startDt': '2020-01-01', 'endDt': '2020-12-31', 'lon': '-75.19083', 'lat': '3.08083', 'variableName': 'agera5-precipitation'}
# {'startDt': '2019-01-01', 'endDt': '2019-12-31', 'lon': '-75.19083', 'lat': '3.08083', 'variableName': 'agera5-precipitation'}
# {'startDt': '2018-01-01', 'endDt': '2018-12-31', 'lon': '-75.19083', 'lat': '3.08083', 'variableName': 'agera5-precipitation'}
# {'startDt': '2017-01-01', 'endDt': '2017-12-31', 'lon': '-75.19083', 'lat': '3.08083', 'variableName': 'agera5-precipitation'}
# {'startDt': '2016-01-01', 'endDt': '2016-12-31', 'lon': '-75.19083', 'lat': '3.08083', 'variableName': 'agera5-precipitation'}
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# Requested from 2019-01-01 to 2019-12-31
# Downloaded file saved to: None
# Requested from 2023-01-01 to 2023-12-31
# Downloaded file saved to: None
# Request for interval ('2024-01-01', '2024-12-31') generated an exception: 500 Server Error: Internal Server Error for url: https://zarr-query-api-rv7rkv4opa-uc.a.run.app/v1/getdataOnePoint
# Requested from 2018-01-01 to 2018-12-31
# Downloaded file saved to: None
# Requested from 2016-01-01 to 2016-12-31
# Downloaded file saved to: None
# Requested from 2022-01-01 to 2022-12-31
# Downloaded file saved to: None
# Requested from 2020-01-01 to 2020-12-31
# Downloaded file saved to: None
# Requested from 2017-01-01 to 2017-12-31
# Downloaded file saved to: None
# Requested from 2021-01-01 to 2021-12-31
# Downloaded file saved to: None
# 3
# 15
# 2024
# 3.24609
# -75.23978
# -75.23978 3.24609
# {'startDt': '2024-01-01', 'endDt': '2024-12-31', 'lon': '-75.23978', 'lat': '3.24609', 'variableName': 'agera5-precipitation'}
# {'startDt': '2023-01-01', 'endDt': '2023-12-31', 'lon': '-75.23978', 'lat': '3.24609', 'variableName': 'agera5-precipitation'}
# {'startDt': '2022-01-01', 'endDt': '2022-12-31', 'lon': '-75.23978', 'lat': '3.24609', 'variableName': 'agera5-precipitation'}
# {'startDt': '2021-01-01', 'endDt': '2021-12-31', 'lon': '-75.23978', 'lat': '3.24609', 'variableName': 'agera5-precipitation'}
# {'startDt': '2020-01-01', 'endDt': '2020-12-31', 'lon': '-75.23978', 'lat': '3.24609', 'variableName': 'agera5-precipitation'}
# {'startDt': '2019-01-01', 'endDt': '2019-12-31', 'lon': '-75.23978', 'lat': '3.24609', 'variableName': 'agera5-precipitation'}
# {'startDt': '2018-01-01', 'endDt': '2018-12-31', 'lon': '-75.23978', 'lat': '3.24609', 'variableName': 'agera5-precipitation'}
# {'startDt': '2017-01-01', 'endDt': '2017-12-31', 'lon': '-75.23978', 'lat': '3.24609', 'variableName': 'agera5-precipitation'}
# {'startDt': '2016-01-01', 'endDt': '2016-12-31', 'lon': '-75.23978', 'lat': '3.24609', 'variableName': 'agera5-precipitation'}
# {'startDt': '2015-01-01', 'endDt': '2015-12-31', 'lon': '-75.23978', 'lat': '3.24609', 'variableName': 'agera5-precipitation'}
# {'startDt': '2014-01-01', 'endDt': '2014-12-31', 'lon': '-75.23978', 'lat': '3.24609', 'variableName': 'agera5-precipitation'}
# {'startDt': '2013-01-01', 'endDt': '2013-12-31', 'lon': '-75.23978', 'lat': '3.24609', 'variableName': 'agera5-precipitation'}
# {'startDt': '2012-01-01', 'endDt': '2012-12-31', 'lon': '-75.23978', 'lat': '3.24609', 'variableName': 'agera5-precipitation'}
# {'startDt': '2011-01-01', 'endDt': '2011-12-31', 'lon': '-75.23978', 'lat': '3.24609', 'variableName': 'agera5-precipitation'}
# {'startDt': '2010-01-01', 'endDt': '2010-12-31', 'lon': '-75.23978', 'lat': '3.24609', 'variableName': 'agera5-precipitation'}
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# Requested from 2012-01-01 to 2012-12-31
# Downloaded file saved to: None
# Requested from 2023-01-01 to 2023-12-31
# Downloaded file saved to: None
# Requested from 2017-01-01 to 2017-12-31
# Downloaded file saved to: None
# Requested from 2014-01-01 to 2014-12-31
# Downloaded file saved to: None
# Requested from 2021-01-01 to 2021-12-31
# Downloaded file saved to: None
# Request for interval ('2024-01-01', '2024-12-31') generated an exception: 500 Server Error: Internal Server Error for url: https://zarr-query-api-rv7rkv4opa-uc.a.run.app/v1/getdataOnePoint
# Requested from 2013-01-01 to 2013-12-31
# Downloaded file saved to: None
# Requested from 2015-01-01 to 2015-12-31
# Downloaded file saved to: None
# Requested from 2020-01-01 to 2020-12-31
# Downloaded file saved to: None
# Requested from 2022-01-01 to 2022-12-31
# Downloaded file saved to: None
# Requested from 2011-01-01 to 2011-12-31
# Downloaded file saved to: None
# Requested from 2010-01-01 to 2010-12-31
# Downloaded file saved to: None
# Requested from 2018-01-01 to 2018-12-31
# Downloaded file saved to: None
# Requested from 2016-01-01 to 2016-12-31
# Downloaded file saved to: None
# Requested from 2019-01-01 to 2019-12-31
# Downloaded file saved to: None
# 4
# 15
# 2024
# 3.30278
# -73.56722
# -73.56722 3.30278
# {'startDt': '2024-01-01', 'endDt': '2024-12-31', 'lon': '-73.56722', 'lat': '3.30278', 'variableName': 'agera5-precipitation'}
# {'startDt': '2023-01-01', 'endDt': '2023-12-31', 'lon': '-73.56722', 'lat': '3.30278', 'variableName': 'agera5-precipitation'}
# {'startDt': '2022-01-01', 'endDt': '2022-12-31', 'lon': '-73.56722', 'lat': '3.30278', 'variableName': 'agera5-precipitation'}
# {'startDt': '2021-01-01', 'endDt': '2021-12-31', 'lon': '-73.56722', 'lat': '3.30278', 'variableName': 'agera5-precipitation'}
# {'startDt': '2020-01-01', 'endDt': '2020-12-31', 'lon': '-73.56722', 'lat': '3.30278', 'variableName': 'agera5-precipitation'}
# {'startDt': '2019-01-01', 'endDt': '2019-12-31', 'lon': '-73.56722', 'lat': '3.30278', 'variableName': 'agera5-precipitation'}
# {'startDt': '2018-01-01', 'endDt': '2018-12-31', 'lon': '-73.56722', 'lat': '3.30278', 'variableName': 'agera5-precipitation'}
# {'startDt': '2017-01-01', 'endDt': '2017-12-31', 'lon': '-73.56722', 'lat': '3.30278', 'variableName': 'agera5-precipitation'}
# {'startDt': '2016-01-01', 'endDt': '2016-12-31', 'lon': '-73.56722', 'lat': '3.30278', 'variableName': 'agera5-precipitation'}
# {'startDt': '2015-01-01', 'endDt': '2015-12-31', 'lon': '-73.56722', 'lat': '3.30278', 'variableName': 'agera5-precipitation'}
# {'startDt': '2014-01-01', 'endDt': '2014-12-31', 'lon': '-73.56722', 'lat': '3.30278', 'variableName': 'agera5-precipitation'}
# {'startDt': '2013-01-01', 'endDt': '2013-12-31', 'lon': '-73.56722', 'lat': '3.30278', 'variableName': 'agera5-precipitation'}
# {'startDt': '2012-01-01', 'endDt': '2012-12-31', 'lon': '-73.56722', 'lat': '3.30278', 'variableName': 'agera5-precipitation'}
# {'startDt': '2011-01-01', 'endDt': '2011-12-31', 'lon': '-73.56722', 'lat': '3.30278', 'variableName': 'agera5-precipitation'}
# {'startDt': '2010-01-01', 'endDt': '2010-12-31', 'lon': '-73.56722', 'lat': '3.30278', 'variableName': 'agera5-precipitation'}
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# Requested from 2018-01-01 to 2018-12-31
# Downloaded file saved to: None
# Requested from 2010-01-01 to 2010-12-31
# Downloaded file saved to: None
# Requested from 2013-01-01 to 2013-12-31
# Downloaded file saved to: None
# Requested from 2023-01-01 to 2023-12-31
# Downloaded file saved to: None
# Request for interval ('2024-01-01', '2024-12-31') generated an exception: 500 Server Error: Internal Server Error for url: https://zarr-query-api-rv7rkv4opa-uc.a.run.app/v1/getdataOnePoint
# Requested from 2012-01-01 to 2012-12-31
# Downloaded file saved to: None
# Requested from 2016-01-01 to 2016-12-31
# Downloaded file saved to: None
# Requested from 2020-01-01 to 2020-12-31
# Downloaded file saved to: None
# Requested from 2011-01-01 to 2011-12-31
# Downloaded file saved to: None
# Requested from 2015-01-01 to 2015-12-31
# Downloaded file saved to: None
# Requested from 2017-01-01 to 2017-12-31
# Downloaded file saved to: None
# Requested from 2021-01-01 to 2021-12-31
# Downloaded file saved to: None
# Requested from 2019-01-01 to 2019-12-31
# Downloaded file saved to: None
# Requested from 2014-01-01 to 2014-12-31
# Downloaded file saved to: None
# Requested from 2022-01-01 to 2022-12-31
# Downloaded file saved to: None
# 5
# 11
# 2024
# 3.67216
# -73.75335
# -73.75335 3.67216
# {'startDt': '2024-01-01', 'endDt': '2024-12-31', 'lon': '-73.75335', 'lat': '3.67216', 'variableName': 'agera5-precipitation'}
# {'startDt': '2023-01-01', 'endDt': '2023-12-31', 'lon': '-73.75335', 'lat': '3.67216', 'variableName': 'agera5-precipitation'}
# {'startDt': '2022-01-01', 'endDt': '2022-12-31', 'lon': '-73.75335', 'lat': '3.67216', 'variableName': 'agera5-precipitation'}
# {'startDt': '2021-01-01', 'endDt': '2021-12-31', 'lon': '-73.75335', 'lat': '3.67216', 'variableName': 'agera5-precipitation'}
# {'startDt': '2020-01-01', 'endDt': '2020-12-31', 'lon': '-73.75335', 'lat': '3.67216', 'variableName': 'agera5-precipitation'}
# {'startDt': '2019-01-01', 'endDt': '2019-12-31', 'lon': '-73.75335', 'lat': '3.67216', 'variableName': 'agera5-precipitation'}
# {'startDt': '2018-01-01', 'endDt': '2018-12-31', 'lon': '-73.75335', 'lat': '3.67216', 'variableName': 'agera5-precipitation'}
# {'startDt': '2017-01-01', 'endDt': '2017-12-31', 'lon': '-73.75335', 'lat': '3.67216', 'variableName': 'agera5-precipitation'}
# {'startDt': '2016-01-01', 'endDt': '2016-12-31', 'lon': '-73.75335', 'lat': '3.67216', 'variableName': 'agera5-precipitation'}
# {'startDt': '2015-01-01', 'endDt': '2015-12-31', 'lon': '-73.75335', 'lat': '3.67216', 'variableName': 'agera5-precipitation'}
# {'startDt': '2014-01-01', 'endDt': '2014-12-31', 'lon': '-73.75335', 'lat': '3.67216', 'variableName': 'agera5-precipitation'}
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# Requested from 2023-01-01 to 2023-12-31
# Downloaded file saved to: None
# Requested from 2016-01-01 to 2016-12-31
# Downloaded file saved to: None
# Requested from 2015-01-01 to 2015-12-31
# Downloaded file saved to: None
# Request for interval ('2024-01-01', '2024-12-31') generated an exception: 500 Server Error: Internal Server Error for url: https://zarr-query-api-rv7rkv4opa-uc.a.run.app/v1/getdataOnePoint
# Requested from 2021-01-01 to 2021-12-31
# Downloaded file saved to: None
# Requested from 2014-01-01 to 2014-12-31
# Downloaded file saved to: None
# Requested from 2022-01-01 to 2022-12-31
# Downloaded file saved to: None
# Requested from 2020-01-01 to 2020-12-31
# Downloaded file saved to: None
# Requested from 2019-01-01 to 2019-12-31
# Downloaded file saved to: None
# Requested from 2018-01-01 to 2018-12-31
# Downloaded file saved to: None
# Requested from 2017-01-01 to 2017-12-31
# Downloaded file saved to: None
# 6
# 15
# 2024
# 3.76035
# -74.92638
# -74.92638 3.76035
# {'startDt': '2024-01-01', 'endDt': '2024-12-31', 'lon': '-74.92638', 'lat': '3.76035', 'variableName': 'agera5-precipitation'}
# {'startDt': '2023-01-01', 'endDt': '2023-12-31', 'lon': '-74.92638', 'lat': '3.76035', 'variableName': 'agera5-precipitation'}
# {'startDt': '2022-01-01', 'endDt': '2022-12-31', 'lon': '-74.92638', 'lat': '3.76035', 'variableName': 'agera5-precipitation'}
# {'startDt': '2021-01-01', 'endDt': '2021-12-31', 'lon': '-74.92638', 'lat': '3.76035', 'variableName': 'agera5-precipitation'}
# {'startDt': '2020-01-01', 'endDt': '2020-12-31', 'lon': '-74.92638', 'lat': '3.76035', 'variableName': 'agera5-precipitation'}
# {'startDt': '2019-01-01', 'endDt': '2019-12-31', 'lon': '-74.92638', 'lat': '3.76035', 'variableName': 'agera5-precipitation'}
# {'startDt': '2018-01-01', 'endDt': '2018-12-31', 'lon': '-74.92638', 'lat': '3.76035', 'variableName': 'agera5-precipitation'}
# {'startDt': '2017-01-01', 'endDt': '2017-12-31', 'lon': '-74.92638', 'lat': '3.76035', 'variableName': 'agera5-precipitation'}
# {'startDt': '2016-01-01', 'endDt': '2016-12-31', 'lon': '-74.92638', 'lat': '3.76035', 'variableName': 'agera5-precipitation'}
# {'startDt': '2015-01-01', 'endDt': '2015-12-31', 'lon': '-74.92638', 'lat': '3.76035', 'variableName': 'agera5-precipitation'}
# {'startDt': '2014-01-01', 'endDt': '2014-12-31', 'lon': '-74.92638', 'lat': '3.76035', 'variableName': 'agera5-precipitation'}
# {'startDt': '2013-01-01', 'endDt': '2013-12-31', 'lon': '-74.92638', 'lat': '3.76035', 'variableName': 'agera5-precipitation'}
# {'startDt': '2011-01-01', 'endDt': '2011-12-31', 'lon': '-74.92638', 'lat': '3.76035', 'variableName': 'agera5-precipitation'}
# {'startDt': '2012-01-01', 'endDt': '2012-12-31', 'lon': '-74.92638', 'lat': '3.76035', 'variableName': 'agera5-precipitation'}
# {'startDt': '2010-01-01', 'endDt': '2010-12-31', 'lon': '-74.92638', 'lat': '3.76035', 'variableName': 'agera5-precipitation'}
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# Requested from 2016-01-01 to 2016-12-31
# Downloaded file saved to: None
# Requested from 2011-01-01 to 2011-12-31
# Downloaded file saved to: None
# Requested from 2020-01-01 to 2020-12-31
# Downloaded file saved to: None
# Requested from 2022-01-01 to 2022-12-31
# Downloaded file saved to: None
# Requested from 2023-01-01 to 2023-12-31
# Downloaded file saved to: None
# Request for interval ('2024-01-01', '2024-12-31') generated an exception: 500 Server Error: Internal Server Error for url: https://zarr-query-api-rv7rkv4opa-uc.a.run.app/v1/getdataOnePoint
# Requested from 2010-01-01 to 2010-12-31
# Downloaded file saved to: None
# Requested from 2015-01-01 to 2015-12-31
# Downloaded file saved to: None
# Requested from 2019-01-01 to 2019-12-31
# Downloaded file saved to: None
# Requested from 2018-01-01 to 2018-12-31
# Downloaded file saved to: None
# Requested from 2012-01-01 to 2012-12-31
# Downloaded file saved to: None
# Requested from 2017-01-01 to 2017-12-31
# Downloaded file saved to: None
# Requested from 2021-01-01 to 2021-12-31
# Downloaded file saved to: None
# Requested from 2013-01-01 to 2013-12-31
# Downloaded file saved to: None
# Requested from 2014-01-01 to 2014-12-31
# Downloaded file saved to: None
# 7
# 14
# 2023
# 3.82888
# -73.68548
# -73.68548 3.82888
# {'startDt': '2023-01-01', 'endDt': '2023-12-31', 'lon': '-73.68548', 'lat': '3.82888', 'variableName': 'agera5-precipitation'}
# {'startDt': '2022-01-01', 'endDt': '2022-12-31', 'lon': '-73.68548', 'lat': '3.82888', 'variableName': 'agera5-precipitation'}
# {'startDt': '2021-01-01', 'endDt': '2021-12-31', 'lon': '-73.68548', 'lat': '3.82888', 'variableName': 'agera5-precipitation'}
# {'startDt': '2020-01-01', 'endDt': '2020-12-31', 'lon': '-73.68548', 'lat': '3.82888', 'variableName': 'agera5-precipitation'}
# {'startDt': '2019-01-01', 'endDt': '2019-12-31', 'lon': '-73.68548', 'lat': '3.82888', 'variableName': 'agera5-precipitation'}
# {'startDt': '2018-01-01', 'endDt': '2018-12-31', 'lon': '-73.68548', 'lat': '3.82888', 'variableName': 'agera5-precipitation'}
# {'startDt': '2017-01-01', 'endDt': '2017-12-31', 'lon': '-73.68548', 'lat': '3.82888', 'variableName': 'agera5-precipitation'}
# {'startDt': '2016-01-01', 'endDt': '2016-12-31', 'lon': '-73.68548', 'lat': '3.82888', 'variableName': 'agera5-precipitation'}
# {'startDt': '2015-01-01', 'endDt': '2015-12-31', 'lon': '-73.68548', 'lat': '3.82888', 'variableName': 'agera5-precipitation'}
# {'startDt': '2014-01-01', 'endDt': '2014-12-31', 'lon': '-73.68548', 'lat': '3.82888', 'variableName': 'agera5-precipitation'}
# {'startDt': '2013-01-01', 'endDt': '2013-12-31', 'lon': '-73.68548', 'lat': '3.82888', 'variableName': 'agera5-precipitation'}
# {'startDt': '2012-01-01', 'endDt': '2012-12-31', 'lon': '-73.68548', 'lat': '3.82888', 'variableName': 'agera5-precipitation'}
# {'startDt': '2011-01-01', 'endDt': '2011-12-31', 'lon': '-73.68548', 'lat': '3.82888', 'variableName': 'agera5-precipitation'}
# {'startDt': '2010-01-01', 'endDt': '2010-12-31', 'lon': '-73.68548', 'lat': '3.82888', 'variableName': 'agera5-precipitation'}
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
# ...
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# Requested from 2018-01-01 to 2018-12-31
# Downloaded file saved to: None
# Requested from 2017-01-01 to 2017-12-31
# Downloaded file saved to: None
# Requested from 2010-01-01 to 2010-12-31
# Downloaded file saved to: None
# Requested from 2015-01-01 to 2015-12-31
# Downloaded file saved to: None
# Requested from 2016-01-01 to 2016-12-31
# Downloaded file saved to: None
# Requested from 2023-01-01 to 2023-12-31
# Downloaded file saved to: None
# Request for interval ('2024-01-01', '2024-12-31') generated an exception: 500 Server Error: Internal Server Error for url: https://zarr-query-api-rv7rkv4opa-uc.a.run.app/v1/getdataOnePoint
# Requested from 2021-01-01 to 2021-12-31
# Downloaded file saved to: None
# Requested from 2020-01-01 to 2020-12-31
# Downloaded file saved to: None
# Requested from 2022-01-01 to 2022-12-31
# Downloaded file saved to: None
# Requested from 2013-01-01 to 2013-12-31
# Downloaded file saved to: None
# Requested from 2014-01-01 to 2014-12-31
# Downloaded file saved to: None
# Requested from 2019-01-01 to 2019-12-31
# Downloaded file saved to: None
# Requested from 2011-01-01 to 2011-12-31
# Downloaded file saved to: None
# Requested from 2012-01-01 to 2012-12-31
# Downloaded file saved to: None
# 40
# 15
# 2024
# 10.62164
# -74.26311
# -74.26311 10.62164
# {'startDt': '2024-01-01', 'endDt': '2024-12-31', 'lon': '-74.26311', 'lat': '10.62164', 'variableName': 'agera5-precipitation'}
# {'startDt': '2023-01-01', 'endDt': '2023-12-31', 'lon': '-74.26311', 'lat': '10.62164', 'variableName': 'agera5-precipitation'}
# {'startDt': '2022-01-01', 'endDt': '2022-12-31', 'lon': '-74.26311', 'lat': '10.62164', 'variableName': 'agera5-precipitation'}
# {'startDt': '2021-01-01', 'endDt': '2021-12-31', 'lon': '-74.26311', 'lat': '10.62164', 'variableName': 'agera5-precipitation'}
# {'startDt': '2020-01-01', 'endDt': '2020-12-31', 'lon': '-74.26311', 'lat': '10.62164', 'variableName': 'agera5-precipitation'}
# {'startDt': '2019-01-01', 'endDt': '2019-12-31', 'lon': '-74.26311', 'lat': '10.62164', 'variableName': 'agera5-precipitation'}
# {'startDt': '2018-01-01', 'endDt': '2018-12-31', 'lon': '-74.26311', 'lat': '10.62164', 'variableName': 'agera5-precipitation'}
# {'startDt': '2017-01-01', 'endDt': '2017-12-31', 'lon': '-74.26311', 'lat': '10.62164', 'variableName': 'agera5-precipitation'}
# {'startDt': '2016-01-01', 'endDt': '2016-12-31', 'lon': '-74.26311', 'lat': '10.62164', 'variableName': 'agera5-precipitation'}
# {'startDt': '2015-01-01', 'endDt': '2015-12-31', 'lon': '-74.26311', 'lat': '10.62164', 'variableName': 'agera5-precipitation'}
# {'startDt': '2014-01-01', 'endDt': '2014-12-31', 'lon': '-74.26311', 'lat': '10.62164', 'variableName': 'agera5-precipitation'}
# {'startDt': '2013-01-01', 'endDt': '2013-12-31', 'lon': '-74.26311', 'lat': '10.62164', 'variableName': 'agera5-precipitation'}
# {'startDt': '2012-01-01', 'endDt': '2012-12-31', 'lon': '-74.26311', 'lat': '10.62164', 'variableName': 'agera5-precipitation'}
# {'startDt': '2011-01-01', 'endDt': '2011-12-31', 'lon': '-74.26311', 'lat': '10.62164', 'variableName': 'agera5-precipitation'}
# {'startDt': '2010-01-01', 'endDt': '2010-12-31', 'lon': '-74.26311', 'lat': '10.62164', 'variableName': 'agera5-precipitation'}
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# Requested from 2022-01-01 to 2022-12-31
# Downloaded file saved to: None
# Requested from 2014-01-01 to 2014-12-31
# Downloaded file saved to: None
# Requested from 2021-01-01 to 2021-12-31
# Downloaded file saved to: None
# Requested from 2013-01-01 to 2013-12-31
# Downloaded file saved to: None
# Requested from 2023-01-01 to 2023-12-31
# Downloaded file saved to: None
# Request for interval ('2024-01-01', '2024-12-31') generated an exception: 500 Server Error: Internal Server Error for url: https://zarr-query-api-rv7rkv4opa-uc.a.run.app/v1/getdataOnePoint
# Requested from 2015-01-01 to 2015-12-31
# Downloaded file saved to: None
# Requested from 2016-01-01 to 2016-12-31
# Downloaded file saved to: None
# Requested from 2011-01-01 to 2011-12-31
# Downloaded file saved to: None
# Requested from 2012-01-01 to 2012-12-31
# Downloaded file saved to: None
# Requested from 2019-01-01 to 2019-12-31
# Downloaded file saved to: None
# Requested from 2020-01-01 to 2020-12-31
# Downloaded file saved to: None
# Requested from 2018-01-01 to 2018-12-31
# Downloaded file saved to: None
# Requested from 2010-01-01 to 2010-12-31
# Downloaded file saved to: None
# Requested from 2017-01-01 to 2017-12-31
# Downloaded file saved to: None
# 41
# 10
# 2023
# 10.87405
# -72.85299
# -72.85299 10.87405
# {'startDt': '2023-01-01', 'endDt': '2023-12-31', 'lon': '-72.85299', 'lat': '10.87405', 'variableName': 'agera5-precipitation'}
# {'startDt': '2022-01-01', 'endDt': '2022-12-31', 'lon': '-72.85299', 'lat': '10.87405', 'variableName': 'agera5-precipitation'}
# {'startDt': '2021-01-01', 'endDt': '2021-12-31', 'lon': '-72.85299', 'lat': '10.87405', 'variableName': 'agera5-precipitation'}
# {'startDt': '2020-01-01', 'endDt': '2020-12-31', 'lon': '-72.85299', 'lat': '10.87405', 'variableName': 'agera5-precipitation'}
# {'startDt': '2019-01-01', 'endDt': '2019-12-31', 'lon': '-72.85299', 'lat': '10.87405', 'variableName': 'agera5-precipitation'}
# {'startDt': '2018-01-01', 'endDt': '2018-12-31', 'lon': '-72.85299', 'lat': '10.87405', 'variableName': 'agera5-precipitation'}
# {'startDt': '2017-01-01', 'endDt': '2017-12-31', 'lon': '-72.85299', 'lat': '10.87405', 'variableName': 'agera5-precipitation'}
# {'startDt': '2016-01-01', 'endDt': '2016-12-31', 'lon': '-72.85299', 'lat': '10.87405', 'variableName': 'agera5-precipitation'}
# {'startDt': '2015-01-01', 'endDt': '2015-12-31', 'lon': '-72.85299', 'lat': '10.87405', 'variableName': 'agera5-precipitation'}
# {'startDt': '2014-01-01', 'endDt': '2014-12-31', 'lon': '-72.85299', 'lat': '10.87405', 'variableName': 'agera5-precipitation'}
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# /home/jupyter/getDataFromCubePoint.py:84: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.json(),orient='records')
# Requested from 2018-01-01 to 2018-12-31
# Downloaded file saved to: None
# Requested from 2014-01-01 to 2014-12-31
# Downloaded file saved to: None
# Requested from 2022-01-01 to 2022-12-31
# Downloaded file saved to: None
# Requested from 2017-01-01 to 2017-12-31
# Downloaded file saved to: None
# Requested from 2023-01-01 to 2023-12-31
# Downloaded file saved to: None
# Requested from 2021-01-01 to 2021-12-31
# Downloaded file saved to: None
# Requested from 2019-01-01 to 2019-12-31
# Downloaded file saved to: None
# Requested from 2016-01-01 to 2016-12-31
# Downloaded file saved to: None
# Requested from 2020-01-01 to 2020-12-31
# Downloaded file saved to: None
# Requested from 2015-01-01 to 2015-12-31
# Downloaded file saved to: None

# %%
hay un problema, dentro del csv la lat y lon no coincide con la que se paso en el request

# %%
# !python getDataFromCubePoint.py --startDate "09-01" --endDate "09-01" --variable "chirps-precipitation" --numberofyears 1 --lastYear 2023 --downloadpath "/home/jupyter/chirps_data/" --x -72.98889 --y 4.39333
