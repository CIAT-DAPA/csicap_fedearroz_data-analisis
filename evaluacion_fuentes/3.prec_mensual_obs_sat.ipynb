# %% [markdown]
# # Monthly data generation

# %%
import pandas as pd
import glob
import os

from geopy.distance import geodesic
import plotly.express as px
import geopandas as gpd

# %%
cd csicap_fedearroz_evaluacion/
# Out:
# [Errno 2] No such file or directory: 'csicap_fedearroz_evaluacion/'
# /home/jupyter/csicap_fedearroz_evaluacion

# %%
info_arroz = pd.read_parquet('data/arroz_obs_sat.parquet')

# %%
info_arroz['month_year'] = info_arroz['date'].dt.to_period('M')
info_arroz.head()
# Out:
#    latitud  longitud  dpto   mun       date  precipitation           station  \
# 0  4.39333 -72.98889  META  UPIA 2015-07-06            0.0  BARRANCA_DE_UPIA
# 1  4.39333 -72.98889  META  UPIA 2015-07-07            0.0  BARRANCA_DE_UPIA
# 2  4.39333 -72.98889  META  UPIA 2015-07-08            NaN  BARRANCA_DE_UPIA
# 3  4.39333 -72.98889  META  UPIA 2015-07-09            NaN  BARRANCA_DE_UPIA
# 4  4.39333 -72.98889  META  UPIA 2015-07-10            NaN  BARRANCA_DE_UPIA
#
#    evento_lluvia     fuente month_year
# 0            0.0  fedearroz    2015-07
# 1            0.0  fedearroz    2015-07
# 2            NaN  fedearroz    2015-07
# 3            NaN  fedearroz    2015-07
# 4            NaN  fedearroz    2015-07

# %% [markdown]
# # monthly events

# %%
def max_consecutive_zeros(series):
    """Función para contar el máximo número de ceros consecutivos."""
    max_count = (series.eq(0).cumsum() - series.eq(0).cumsum().where(~series.eq(0)).ffill().fillna(0)).max()
    return max_count


summary = info_arroz[info_arroz.fuente=='fedearroz'].groupby(['dpto','mun','station', 'month_year']).agg(
    num_registros=('precipitation', 'size'),
    num_nans=('precipitation', lambda x: x.isna().sum()),
    num_ceros=('precipitation', lambda x: (x == 0).sum()),
    max_ceros_consecutivos=('precipitation', lambda x: max_consecutive_zeros(x))
).reset_index()
summary.head()
# Out:
#         dpto    mun                      station month_year  num_registros  \
# 0  ANTIOQUIA  NECHI  FEDEARROZ_NECHI_SANTA_CLARA    2011-09              8
# 1  ANTIOQUIA  NECHI  FEDEARROZ_NECHI_SANTA_CLARA    2011-10             31
# 2  ANTIOQUIA  NECHI  FEDEARROZ_NECHI_SANTA_CLARA    2011-11             30
# 3  ANTIOQUIA  NECHI  FEDEARROZ_NECHI_SANTA_CLARA    2011-12             31
# 4  ANTIOQUIA  NECHI  FEDEARROZ_NECHI_SANTA_CLARA    2012-01             31
#
#    num_nans  num_ceros  max_ceros_consecutivos
# 0         0          4                     2.0
# 1         0          8                     6.0
# 2         0          6                     1.0
# 3         0         11                     4.0
# 4         0         28                    20.0

# %%
summary.to_excel('data/summary_monthly_prec.xlsx')

# %% [markdown]
# # monthly aggregation

# %%
# hasta 3 dias faltantes para que se agrege el mes
filtered_missing_data_count = summary[summary['num_nans'] <= 3]

# %%
info_arroz_filtered = pd.merge(info_arroz, filtered_missing_data_count[['station', 'month_year']], 
                               on=['station', 'month_year'], how='inner')


sum_prec_obs = info_arroz_filtered.groupby(['latitud','longitud','dpto','mun','station', 'month_year', 'fuente']).agg(prec_month=('precipitation','sum')).reset_index()
sum_prec_obs
# Out:
#         latitud  longitud     dpto          mun  \
# 0       2.69814 -75.29815    HUILA  CAMPOALEGRE
# 1       2.69814 -75.29815    HUILA  CAMPOALEGRE
# 2       2.69814 -75.29815    HUILA  CAMPOALEGRE
# 3       2.69814 -75.29815    HUILA  CAMPOALEGRE
# 4       2.69814 -75.29815    HUILA  CAMPOALEGRE
# ...         ...       ...      ...          ...
# 11851  10.87405 -72.85299  GUAJIRA      FONSECA
# 11852  10.87405 -72.85299  GUAJIRA      FONSECA
# 11853  10.87405 -72.85299  GUAJIRA      FONSECA
# 11854  10.87405 -72.85299  GUAJIRA      FONSECA
# 11855  10.87405 -72.85299  GUAJIRA      FONSECA
#
#                                 station month_year                fuente  \
# 0      FEDEARROZ_CAMPOALEGRE_ALTAGRACIA    2011-11  agera5-precipitation
# 1      FEDEARROZ_CAMPOALEGRE_ALTAGRACIA    2011-11  chirps-precipitation
# 2      FEDEARROZ_CAMPOALEGRE_ALTAGRACIA    2011-11             fedearroz
# 3      FEDEARROZ_CAMPOALEGRE_ALTAGRACIA    2011-12  agera5-precipitation
# 4      FEDEARROZ_CAMPOALEGRE_ALTAGRACIA    2011-12  chirps-precipitation
# ...                                 ...        ...                   ...
# 11851      FEDEARROZ_FONSECA_GRANJA_ITA    2023-11  chirps-precipitation
# 11852      FEDEARROZ_FONSECA_GRANJA_ITA    2023-11             fedearroz
# 11853      FEDEARROZ_FONSECA_GRANJA_ITA    2023-12  agera5-precipitation
# 11854      FEDEARROZ_FONSECA_GRANJA_ITA    2023-12  chirps-precipitation
# 11855      FEDEARROZ_FONSECA_GRANJA_ITA    2023-12             fedearroz
#
#        prec_month
# 0      228.520000
# 1      436.494230
# 2      513.200000
# 3      164.050001
# 4      242.482750
# ...           ...
# 11851  190.283857
# 11852  412.410000
# 11853   26.520000
# 11854   15.484619
# 11855    0.250000
#
# [11856 rows x 8 columns]

# %%
sum_prec_obs.to_parquet('data/prec_monthly_obs_sat.parquet')
